# %%
import pandas as pd
import json
import sqlite3

# %%
try:
    # Reading in CSV data
    phone_df = pd.read_csv('user_behavior_dataset.csv', index_col=False)
    # Showing Input
    print("# of cols:", len(phone_df.count()))
    print("# of records:", len(phone_df.count('columns')))
    phone_df.head()
except:
    print("Something went wrong reading in the CSV data. Check your filepath.")
# Out:
# # of cols: 11
# # of records: 700

# %%
try:
    # Reading in JSON Data
    with open('all_hour.geojson.json') as f:
        earthquake_json = json.load(f)
        # Showing Input
        numCols = 0
        for i in pd.json_normalize(earthquake_json['features']):
            numCols += 1
        print("# of cols:", numCols)
        print("# of records:", len(earthquake_json['features']), "\n")
        print(json.dumps(earthquake_json, indent=4))
except:
    print("Something went wrong reading in the JSON data. Check your filepath.")
# Out:
# # of cols: 30
# # of records: 9
#
# {
#     "type": "FeatureCollection",
#     "metadata": {
#         "generated": 1729468344000,
#         "url": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_hour.geojson",
#         "title": "USGS All Earthquakes, Past Hour",
#         "status": 200,
#         "api": "1.14.1",
#         "count": 9
#     },
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.6,
#                 "place": "17 km NE of Petersville, Alaska",
#                 "time": 1729467261342,
#                 "updated": 1729467382777,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilwc3a",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilwc3a.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 39,
#                 "net": "ak",
#                 "code": "024dilwc3a",
#                 "ids": ",ak024dilwc3a,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 1.19,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.6 - 17 km NE of Petersville, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -150.5302,
#                     62.6138,
#                     16.9
#                 ]
#             },
#             "id": "ak024dilwc3a"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.02,
#                 "place": "7 km NW of Parkfield, CA",
#                 "time": 1729466916860,
#                 "updated": 1729467014777,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75076581",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75076581.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 16,
#                 "net": "nc",
#                 "code": "75076581",
#                 "ids": ",nc75076581,",
#                 "sources": ",nc,",
#                 "types": ",nearby-cities,origin,phase-data,",
#                 "nst": 11,
#                 "dmin": 0.01546,
#                 "rms": 0.05,
#                 "gap": 148,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.0 - 7 km NW of Parkfield, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -120.488670349121,
#                     35.9396667480469,
#                     9.86999988555908
#                 ]
#             },
#             "id": "nc75076581"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 5,
#                 "place": "166 km NNW of Sola, Vanuatu",
#                 "time": 1729466537999,
#                 "updated": 1729467505040,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000nzxu",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nzxu.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 385,
#                 "net": "us",
#                 "code": "6000nzxu",
#                 "ids": ",us6000nzxu,",
#                 "sources": ",us,",
#                 "types": ",origin,phase-data,",
#                 "nst": 54,
#                 "dmin": 8.431,
#                 "rms": 0.55,
#                 "gap": 53,
#                 "magType": "mb",
#                 "type": "earthquake",
#                 "title": "M 5.0 - 166 km NNW of Sola, Vanuatu"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     166.9805,
#                     -12.479,
#                     205.772
#                 ]
#             },
#             "id": "us6000nzxu"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.4,
#                 "place": "25 km NW of Valdez, Alaska",
#                 "time": 1729466370088,
#                 "updated": 1729466462327,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilt50w",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilt50w.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 30,
#                 "net": "ak",
#                 "code": "024dilt50w",
#                 "ids": ",ak024dilt50w,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.2,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.4 - 25 km NW of Valdez, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -146.7151,
#                     61.2805,
#                     27.9
#                 ]
#             },
#             "id": "ak024dilt50w"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 2.47,
#                 "place": "42 km NE of San Clemente Is. (SE tip), CA",
#                 "time": 1729466197470,
#                 "updated": 1729466612848,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci40958112",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40958112.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 94,
#                 "net": "ci",
#                 "code": "40958112",
#                 "ids": ",ci40958112,",
#                 "sources": ",ci,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 37,
#                 "dmin": 0.4044,
#                 "rms": 0.28,
#                 "gap": 127,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 2.5 - 42 km NE of San Clemente Is. (SE tip), CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.9855,
#                     33.054,
#                     13.1
#                 ]
#             },
#             "id": "ci40958112"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 3.07,
#                 "place": "41 km NE of San Clemente Is. (SE tip), CA",
#                 "time": 1729465918070,
#                 "updated": 1729466722507,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci40958104",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40958104.geojson",
#                 "felt": 4,
#                 "cdi": 2,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 146,
#                 "net": "ci",
#                 "code": "40958104",
#                 "ids": ",ci40958104,us6000nzxl,",
#                 "sources": ",ci,us,",
#                 "types": ",dyfi,nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 76,
#                 "dmin": 0.4196,
#                 "rms": 0.38,
#                 "gap": 182,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 3.1 - 41 km NE of San Clemente Is. (SE tip), CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -117.9840012,
#                     33.0336685,
#                     5.54
#                 ]
#             },
#             "id": "ci40958104"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.2,
#                 "place": "10 km ENE of Fox, Alaska",
#                 "time": 1729465621578,
#                 "updated": 1729465736503,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilqi8d",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilqi8d.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 22,
#                 "net": "ak",
#                 "code": "024dilqi8d",
#                 "ids": ",ak024dilqi8d,",
#                 "sources": ",ak,",
#                 "types": ",origin,phase-data,",
#                 "nst": null,
#                 "dmin": null,
#                 "rms": 0.34,
#                 "gap": null,
#                 "magType": "ml",
#                 "type": "earthquake",
#                 "title": "M 1.2 - 10 km ENE of Fox, Alaska"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -147.3996,
#                     64.9836,
#                     3.8
#                 ]
#             },
#             "id": "ak024dilqi8d"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 5.7,
#                 "place": "63 km NNW of Albard\u00f3n, Argentina",
#                 "time": 1729465180810,
#                 "updated": 1729468291987,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000nzxj",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nzxj.geojson",
#                 "felt": 19,
#                 "cdi": 4.3,
#                 "mmi": 4.145,
#                 "alert": "green",
#                 "status": "reviewed",
#                 "tsunami": 0,
#                 "sig": 508,
#                 "net": "us",
#                 "code": "6000nzxj",
#                 "ids": ",us6000nzxj,",
#                 "sources": ",us,",
#                 "types": ",dyfi,losspager,moment-tensor,origin,phase-data,shakemap,",
#                 "nst": 32,
#                 "dmin": 0.652,
#                 "rms": 0.53,
#                 "gap": 89,
#                 "magType": "mww",
#                 "type": "earthquake",
#                 "title": "M 5.7 - 63 km NNW of Albard\u00f3n, Argentina"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -68.7474,
#                     -30.8936,
#                     107.654
#                 ]
#             },
#             "id": "us6000nzxj"
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "mag": 1.5,
#                 "place": "9 km ENE of Cayucos, CA",
#                 "time": 1729464938110,
#                 "updated": 1729467867923,
#                 "tz": null,
#                 "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75076571",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75076571.geojson",
#                 "felt": null,
#                 "cdi": null,
#                 "mmi": null,
#                 "alert": null,
#                 "status": "automatic",
#                 "tsunami": 0,
#                 "sig": 35,
#                 "net": "nc",
#                 "code": "75076571",
#                 "ids": ",nc75076571,",
#                 "sources": ",nc,",
#                 "types": ",nearby-cities,origin,phase-data,scitech-link,",
#                 "nst": 10,
#                 "dmin": 0.07483,
#                 "rms": 0.05,
#                 "gap": 96,
#                 "magType": "md",
#                 "type": "earthquake",
#                 "title": "M 1.5 - 9 km ENE of Cayucos, CA"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -120.797836303711,
#                     35.4781684875488,
#                     6.44000005722046
#                 ]
#             },
#             "id": "nc75076571"
#         }
#     ],
#     "bbox": [
#         -150.5302,
#         -30.8936,
#         3.8,
#         166.9805,
#         64.9836,
#         205.772
#     ]
# }

# %%
try:
    # Create SQLite DB
    connection = sqlite3.connect('phone_data.db')
    cursor = connection.cursor()
    cursor.execute("drop table if exists phoneData")
    cursor.execute("drop table if exists quakeData")
except:
    print("Something went wrong connecting to the SQLite database")

# %%
# Input first transformation output type
out_format = ""

while out_format != "SQL" and out_format != "JSON":
    out_format = input("""
Into which data structure should the CSV phone data be transformed?\n
> SQL
> JSON\n
    """).upper()
# Out:
# Into which data structure should the CSV phone data be transformed?
#
# > SQL
# > JSON
#
#      sql

# %%
# Input second transformation output type
out_format_2 = ""

while out_format_2 != "CSV" and out_format_2 != "SQL":
    out_format_2 = input("""
Into which data structure should the JSON earthquake data be transformed?\n
> CSV
> SQL\n
    """).upper()
# Out:
# Into which data structure should the JSON earthquake data be transformed?
#
# > CSV
# > SQL
#
#      sql

# %%
try:
    # Dropping 2 Columns
    phone_df.drop(columns=['Number of Apps Installed', 'User Behavior Class'], inplace=True)
except:
    print("Something went wrong dropping columns from the DataFrame. Make sure they haven't already been removed.") 

# Convert CSV data to JSON
if out_format == "JSON":
    try:
        phone_json = json.loads(phone_df.to_json(orient='table'))
        # Showing Output
        print("# of cols:", len(phone_json['schema']['fields']) - 1)
        print("# of records:", len(phone_json['data']), "\n")
        print(json.dumps(phone_json, indent=4))
        # Writing JSON data to file
        with open('phone.json', 'w') as f:
            json.dump(phone_json, f)
    except:
        print("Something went wrong converting the CSV to JSON or in writing the JSON file. Check your output filepath.")

# Convert CSV data to SQL table
else:
    try:
        phone_df.to_sql('phoneData', connection)
    
        # Showing Output
        numCols = 0
        for row in cursor.execute("pragma table_info(phoneData)"):
            numCols += 1
        print("# of cols:", numCols - 1)
        print("# of records:", len(cursor.execute("select * from phoneData").fetchall()), "\n")
        rows = cursor.execute("""
        select * from phoneData
        """)
        for row in rows:
            print(row)
    except:
        print("Something went wrong converting the CSV to SQL on in writing to the database. Check that the table doesn't already exist.")
# Out:
# # of cols: 9
# # of records: 700
#
# (0, 1, 'Google Pixel 5', 'Android', 393, 6.4, 1872, 1122, 40, 'Male')
# (1, 2, 'OnePlus 9', 'Android', 268, 4.7, 1331, 944, 47, 'Female')
# (2, 3, 'Xiaomi Mi 11', 'Android', 154, 4.0, 761, 322, 42, 'Male')
# (3, 4, 'Google Pixel 5', 'Android', 239, 4.8, 1676, 871, 20, 'Male')
# (4, 5, 'iPhone 12', 'iOS', 187, 4.3, 1367, 988, 31, 'Female')
# (5, 6, 'Google Pixel 5', 'Android', 99, 2.0, 940, 564, 31, 'Male')
# (6, 7, 'Samsung Galaxy S21', 'Android', 350, 7.3, 1802, 1054, 21, 'Female')
# (7, 8, 'OnePlus 9', 'Android', 543, 11.4, 2956, 1702, 31, 'Male')
# (8, 9, 'Samsung Galaxy S21', 'Android', 340, 7.7, 2138, 1053, 42, 'Female')
# (9, 10, 'iPhone 12', 'iOS', 424, 6.6, 1957, 1301, 42, 'Male')
# (10, 11, 'Google Pixel 5', 'Android', 53, 1.4, 435, 162, 34, 'Female')
# (11, 12, 'OnePlus 9', 'Android', 215, 5.5, 1690, 641, 24, 'Male')
# (12, 13, 'OnePlus 9', 'Android', 462, 6.2, 2303, 1099, 57, 'Female')
# (13, 14, 'Xiaomi Mi 11', 'Android', 215, 4.9, 1662, 857, 43, 'Male')
# (14, 15, 'iPhone 12', 'iOS', 189, 5.4, 1754, 779, 49, 'Female')
# (15, 16, 'Google Pixel 5', 'Android', 503, 10.4, 2571, 2025, 39, 'Female')
# (16, 17, 'OnePlus 9', 'Android', 132, 3.6, 628, 344, 47, 'Female')
# (17, 18, 'iPhone 12', 'iOS', 299, 5.8, 1431, 985, 44, 'Female')
# (18, 19, 'Google Pixel 5', 'Android', 81, 1.4, 558, 297, 26, 'Female')
# (19, 20, 'iPhone 12', 'iOS', 577, 8.5, 2774, 2192, 29, 'Female')
# (20, 21, 'Samsung Galaxy S21', 'Android', 93, 2.6, 681, 302, 45, 'Female')
# (21, 22, 'OnePlus 9', 'Android', 576, 11.6, 2803, 1553, 43, 'Female')
# (22, 23, 'Samsung Galaxy S21', 'Android', 423, 6.5, 2094, 1372, 23, 'Female')
# (23, 24, 'Google Pixel 5', 'Android', 292, 5.6, 1401, 949, 37, 'Female')
# (24, 25, 'OnePlus 9', 'Android', 216, 4.0, 1711, 748, 58, 'Male')
# (25, 26, 'Samsung Galaxy S21', 'Android', 91, 3.4, 1073, 451, 52, 'Male')
# (26, 27, 'iPhone 12', 'iOS', 444, 7.6, 2372, 1002, 29, 'Male')
# (27, 28, 'Google Pixel 5', 'Android', 512, 10.5, 2409, 1599, 33, 'Male')
# (28, 29, 'OnePlus 9', 'Android', 452, 6.8, 2387, 1456, 55, 'Female')
# (29, 30, 'Samsung Galaxy S21', 'Android', 412, 6.2, 1899, 1384, 19, 'Female')
# (30, 31, 'Xiaomi Mi 11', 'Android', 260, 6.0, 1361, 889, 37, 'Female')
# (31, 32, 'Xiaomi Mi 11', 'Android', 197, 4.6, 1660, 975, 25, 'Male')
# (32, 33, 'Google Pixel 5', 'Android', 278, 4.7, 1484, 917, 21, 'Male')
# (33, 34, 'Google Pixel 5', 'Android', 46, 2.0, 457, 105, 58, 'Male')
# (34, 35, 'Xiaomi Mi 11', 'Android', 593, 10.2, 2499, 1616, 38, 'Female')
# (35, 36, 'Samsung Galaxy S21', 'Android', 32, 1.2, 580, 153, 20, 'Female')
# (36, 37, 'iPhone 12', 'iOS', 122, 3.3, 755, 573, 26, 'Male')
# (37, 38, 'Samsung Galaxy S21', 'Android', 522, 11.2, 2808, 2328, 24, 'Male')
# (38, 39, 'OnePlus 9', 'Android', 473, 6.4, 2312, 1400, 40, 'Male')
# (39, 40, 'Samsung Galaxy S21', 'Android', 398, 6.2, 1851, 1180, 23, 'Male')
# (40, 41, 'Xiaomi Mi 11', 'Android', 240, 4.7, 1464, 708, 56, 'Female')
# (41, 42, 'OnePlus 9', 'Android', 576, 10.1, 2447, 2323, 33, 'Male')
# (42, 43, 'Samsung Galaxy S21', 'Android', 120, 2.1, 720, 392, 43, 'Male')
# (43, 44, 'Samsung Galaxy S21', 'Android', 152, 3.7, 993, 429, 18, 'Male')
# (44, 45, 'Xiaomi Mi 11', 'Android', 138, 2.4, 837, 572, 56, 'Female')
# (45, 46, 'Xiaomi Mi 11', 'Android', 502, 10.9, 2476, 1935, 39, 'Male')
# (46, 47, 'OnePlus 9', 'Android', 558, 8.4, 2447, 1594, 22, 'Female')
# (47, 48, 'Samsung Galaxy S21', 'Android', 138, 3.6, 889, 323, 27, 'Female')
# (48, 49, 'Google Pixel 5', 'Android', 580, 8.2, 2623, 2262, 49, 'Male')
# (49, 50, 'OnePlus 9', 'Android', 589, 8.7, 2736, 1997, 49, 'Male')
# (50, 51, 'Xiaomi Mi 11', 'Android', 452, 7.4, 2180, 1417, 54, 'Female')
# (51, 52, 'Xiaomi Mi 11', 'Android', 245, 5.9, 1243, 885, 29, 'Male')
# (52, 53, 'Samsung Galaxy S21', 'Android', 125, 2.7, 690, 393, 27, 'Female')
# (53, 54, 'Xiaomi Mi 11', 'Android', 97, 2.2, 1101, 375, 53, 'Male')
# (54, 55, 'Google Pixel 5', 'Android', 516, 8.7, 2857, 2189, 53, 'Female')
# (55, 56, 'iPhone 12', 'iOS', 68, 1.6, 450, 111, 30, 'Male')
# (56, 57, 'OnePlus 9', 'Android', 64, 1.1, 572, 161, 42, 'Female')
# (57, 58, 'OnePlus 9', 'Android', 539, 8.4, 2796, 2415, 26, 'Male')
# (58, 59, 'Xiaomi Mi 11', 'Android', 428, 7.0, 2306, 1144, 22, 'Male')
# (59, 60, 'iPhone 12', 'iOS', 325, 7.1, 2269, 1053, 56, 'Male')
# (60, 61, 'Xiaomi Mi 11', 'Android', 522, 11.9, 2798, 1663, 28, 'Female')
# (61, 62, 'Xiaomi Mi 11', 'Android', 309, 7.5, 2292, 1253, 57, 'Female')
# (62, 63, 'Xiaomi Mi 11', 'Android', 79, 1.9, 493, 128, 55, 'Male')
# (63, 64, 'Xiaomi Mi 11', 'Android', 545, 11.5, 2911, 1717, 21, 'Female')
# (64, 65, 'Samsung Galaxy S21', 'Android', 459, 7.0, 1982, 1091, 43, 'Male')
# (65, 66, 'iPhone 12', 'iOS', 225, 4.0, 1420, 917, 56, 'Male')
# (66, 67, 'iPhone 12', 'iOS', 257, 4.5, 1705, 912, 55, 'Male')
# (67, 68, 'Xiaomi Mi 11', 'Android', 134, 4.0, 773, 449, 28, 'Female')
# (68, 69, 'iPhone 12', 'iOS', 516, 10.2, 2932, 1547, 31, 'Male')
# (69, 70, 'Google Pixel 5', 'Android', 82, 1.7, 558, 284, 29, 'Female')
# (70, 71, 'Samsung Galaxy S21', 'Android', 452, 7.2, 1808, 1090, 45, 'Female')
# (71, 72, 'iPhone 12', 'iOS', 521, 9.0, 2902, 1701, 37, 'Male')
# (72, 73, 'Google Pixel 5', 'Android', 457, 6.3, 2347, 1082, 22, 'Male')
# (73, 74, 'Xiaomi Mi 11', 'Android', 31, 1.1, 585, 208, 50, 'Female')
# (74, 75, 'iPhone 12', 'iOS', 47, 2.0, 476, 125, 39, 'Male')
# (75, 76, 'Xiaomi Mi 11', 'Android', 229, 5.7, 1305, 985, 23, 'Female')
# (76, 77, 'Xiaomi Mi 11', 'Android', 34, 2.0, 558, 122, 54, 'Female')
# (77, 78, 'Google Pixel 5', 'Android', 173, 2.5, 678, 301, 30, 'Female')
# (78, 79, 'Samsung Galaxy S21', 'Android', 78, 1.8, 333, 138, 51, 'Female')
# (79, 80, 'Google Pixel 5', 'Android', 230, 5.7, 1254, 989, 34, 'Female')
# (80, 81, 'OnePlus 9', 'Android', 565, 10.6, 2475, 1603, 51, 'Female')
# (81, 82, 'iPhone 12', 'iOS', 172, 2.8, 1035, 549, 41, 'Male')
# (82, 83, 'Xiaomi Mi 11', 'Android', 330, 7.2, 2363, 1133, 21, 'Female')
# (83, 84, 'Xiaomi Mi 11', 'Android', 39, 1.8, 368, 105, 19, 'Male')
# (84, 85, 'Google Pixel 5', 'Android', 223, 4.5, 1311, 695, 33, 'Female')
# (85, 86, 'Google Pixel 5', 'Android', 404, 7.4, 2081, 1352, 44, 'Male')
# (86, 87, 'Samsung Galaxy S21', 'Android', 151, 2.4, 1003, 392, 39, 'Male')
# (87, 88, 'Samsung Galaxy S21', 'Android', 34, 1.5, 345, 276, 44, 'Male')
# (88, 89, 'Xiaomi Mi 11', 'Android', 137, 3.3, 839, 348, 34, 'Female')
# (89, 90, 'Samsung Galaxy S21', 'Android', 301, 6.2, 2053, 1303, 45, 'Male')
# (90, 91, 'Google Pixel 5', 'Android', 116, 2.1, 912, 307, 40, 'Female')
# (91, 92, 'Google Pixel 5', 'Android', 291, 4.1, 1474, 827, 32, 'Female')
# (92, 93, 'iPhone 12', 'iOS', 84, 1.4, 501, 284, 56, 'Female')
# (93, 94, 'iPhone 12', 'iOS', 134, 2.5, 1125, 367, 35, 'Male')
# (94, 95, 'Samsung Galaxy S21', 'Android', 411, 7.5, 2169, 1083, 58, 'Male')
# (95, 96, 'Xiaomi Mi 11', 'Android', 326, 7.2, 2243, 1454, 50, 'Male')
# (96, 97, 'iPhone 12', 'iOS', 550, 9.5, 2916, 1946, 20, 'Male')
# (97, 98, 'OnePlus 9', 'Android', 516, 12.0, 2406, 1968, 28, 'Female')
# (98, 99, 'Google Pixel 5', 'Android', 59, 1.2, 361, 293, 25, 'Female')
# (99, 100, 'OnePlus 9', 'Android', 225, 5.5, 1526, 875, 50, 'Female')
# (100, 101, 'Google Pixel 5', 'Android', 41, 1.1, 389, 136, 53, 'Male')
# (101, 102, 'OnePlus 9', 'Android', 183, 4.1, 1210, 738, 19, 'Male')
# (102, 103, 'Google Pixel 5', 'Android', 174, 2.5, 929, 565, 32, 'Female')
# (103, 104, 'Xiaomi Mi 11', 'Android', 274, 4.2, 1781, 934, 28, 'Male')
# (104, 105, 'Xiaomi Mi 11', 'Android', 166, 2.8, 1113, 360, 25, 'Male')
# (105, 106, 'Xiaomi Mi 11', 'Android', 66, 1.2, 585, 264, 36, 'Male')
# (106, 107, 'Google Pixel 5', 'Android', 152, 2.7, 642, 596, 55, 'Male')
# (107, 108, 'Google Pixel 5', 'Android', 54, 1.4, 403, 278, 23, 'Female')
# (108, 109, 'Xiaomi Mi 11', 'Android', 187, 5.5, 1754, 711, 50, 'Female')
# (109, 110, 'OnePlus 9', 'Android', 216, 6.0, 1641, 889, 39, 'Female')
# (110, 111, 'OnePlus 9', 'Android', 95, 3.8, 718, 459, 41, 'Female')
# (111, 112, 'Xiaomi Mi 11', 'Android', 488, 8.6, 2447, 2344, 19, 'Male')
# (112, 113, 'Google Pixel 5', 'Android', 295, 5.1, 1483, 748, 27, 'Female')
# (113, 114, 'Samsung Galaxy S21', 'Android', 136, 3.2, 818, 404, 42, 'Male')
# (114, 115, 'Xiaomi Mi 11', 'Android', 471, 7.9, 2156, 1324, 54, 'Female')
# (115, 116, 'iPhone 12', 'iOS', 121, 3.2, 651, 596, 39, 'Male')
# (116, 117, 'iPhone 12', 'iOS', 75, 1.2, 409, 281, 18, 'Male')
# (117, 118, 'iPhone 12', 'iOS', 220, 5.2, 1631, 909, 27, 'Female')
# (118, 119, 'Samsung Galaxy S21', 'Android', 82, 1.6, 590, 124, 28, 'Female')
# (119, 120, 'Google Pixel 5', 'Android', 97, 2.7, 1018, 428, 41, 'Male')
# (120, 121, 'Samsung Galaxy S21', 'Android', 388, 6.6, 2085, 1150, 45, 'Female')
# (121, 122, 'OnePlus 9', 'Android', 529, 8.7, 2484, 2189, 39, 'Female')
# (122, 123, 'Google Pixel 5', 'Android', 584, 10.0, 2541, 2391, 49, 'Female')
# (123, 124, 'Google Pixel 5', 'Android', 529, 8.1, 2686, 1924, 35, 'Male')
# (124, 125, 'Google Pixel 5', 'Android', 227, 5.1, 1702, 714, 21, 'Male')
# (125, 126, 'Samsung Galaxy S21', 'Android', 535, 11.8, 2858, 2378, 50, 'Male')
# (126, 127, 'iPhone 12', 'iOS', 332, 7.4, 2149, 1321, 20, 'Female')
# (127, 128, 'Google Pixel 5', 'Android', 252, 4.2, 1439, 667, 50, 'Female')
# (128, 129, 'Xiaomi Mi 11', 'Android', 125, 2.5, 678, 465, 31, 'Male')
# (129, 130, 'Xiaomi Mi 11', 'Android', 97, 3.3, 751, 412, 36, 'Female')
# (130, 131, 'Google Pixel 5', 'Android', 540, 10.8, 2923, 1886, 40, 'Male')
# (131, 132, 'Xiaomi Mi 11', 'Android', 320, 7.2, 2056, 1226, 52, 'Female')
# (132, 133, 'Google Pixel 5', 'Android', 176, 3.6, 1193, 458, 40, 'Female')
# (133, 134, 'Samsung Galaxy S21', 'Android', 79, 1.0, 313, 139, 42, 'Male')
# (134, 135, 'Xiaomi Mi 11', 'Android', 83, 1.6, 303, 285, 51, 'Male')
# (135, 136, 'iPhone 12', 'iOS', 555, 11.3, 2528, 1856, 55, 'Female')
# (136, 137, 'Samsung Galaxy S21', 'Android', 66, 1.7, 375, 216, 39, 'Male')
# (137, 138, 'Xiaomi Mi 11', 'Android', 237, 4.5, 1368, 868, 24, 'Female')
# (138, 139, 'Samsung Galaxy S21', 'Android', 497, 9.7, 2876, 2076, 18, 'Male')
# (139, 140, 'Google Pixel 5', 'Android', 516, 11.1, 2429, 1796, 53, 'Male')
# (140, 141, 'Xiaomi Mi 11', 'Android', 219, 5.2, 1510, 655, 50, 'Female')
# (141, 142, 'Google Pixel 5', 'Android', 448, 6.3, 2044, 1337, 51, 'Male')
# (142, 143, 'iPhone 12', 'iOS', 156, 2.2, 896, 429, 57, 'Female')
# (143, 144, 'Samsung Galaxy S21', 'Android', 68, 1.1, 528, 201, 29, 'Male')
# (144, 145, 'iPhone 12', 'iOS', 524, 11.2, 2417, 2069, 29, 'Female')
# (145, 146, 'iPhone 12', 'iOS', 188, 5.3, 1281, 974, 35, 'Male')
# (146, 147, 'Samsung Galaxy S21', 'Android', 443, 7.4, 2289, 1026, 33, 'Male')
# (147, 148, 'Xiaomi Mi 11', 'Android', 52, 1.6, 385, 234, 24, 'Male')
# (148, 149, 'OnePlus 9', 'Android', 228, 4.2, 1677, 823, 56, 'Male')
# (149, 150, 'Google Pixel 5', 'Android', 149, 3.7, 873, 459, 51, 'Male')
# (150, 151, 'iPhone 12', 'iOS', 523, 9.4, 2583, 1539, 21, 'Male')
# (151, 152, 'Samsung Galaxy S21', 'Android', 42, 1.6, 315, 207, 52, 'Female')
# (152, 153, 'Google Pixel 5', 'Android', 120, 2.0, 741, 396, 56, 'Female')
# (153, 154, 'OnePlus 9', 'Android', 329, 7.5, 2277, 1185, 27, 'Female')
# (154, 155, 'Xiaomi Mi 11', 'Android', 68, 1.5, 364, 102, 31, 'Female')
# (155, 156, 'Xiaomi Mi 11', 'Android', 158, 3.4, 893, 493, 32, 'Male')
# (156, 157, 'Xiaomi Mi 11', 'Android', 86, 1.7, 439, 136, 54, 'Male')
# (157, 158, 'Xiaomi Mi 11', 'Android', 339, 7.8, 2102, 1062, 51, 'Male')
# (158, 159, 'Samsung Galaxy S21', 'Android', 304, 6.5, 2375, 1493, 51, 'Male')
# (159, 160, 'Xiaomi Mi 11', 'Android', 131, 2.4, 859, 305, 40, 'Male')
# (160, 161, 'Samsung Galaxy S21', 'Android', 64, 1.6, 540, 262, 35, 'Female')
# (161, 162, 'Xiaomi Mi 11', 'Android', 53, 1.9, 526, 112, 42, 'Male')
# (162, 163, 'Google Pixel 5', 'Android', 442, 7.7, 2067, 1440, 45, 'Male')
# (163, 164, 'iPhone 12', 'iOS', 32, 2.0, 469, 139, 22, 'Male')
# (164, 165, 'Xiaomi Mi 11', 'Android', 278, 4.8, 1238, 851, 43, 'Female')
# (165, 166, 'Xiaomi Mi 11', 'Android', 540, 8.4, 2993, 1540, 49, 'Female')
# (166, 167, 'Google Pixel 5', 'Android', 595, 11.3, 2968, 2366, 30, 'Male')
# (167, 168, 'Google Pixel 5', 'Android', 35, 1.5, 467, 158, 58, 'Male')
# (168, 169, 'Google Pixel 5', 'Android', 225, 5.4, 1370, 791, 55, 'Female')
# (169, 170, 'Google Pixel 5', 'Android', 587, 11.8, 2431, 1894, 47, 'Male')
# (170, 171, 'Xiaomi Mi 11', 'Android', 92, 3.7, 1124, 524, 44, 'Male')
# (171, 172, 'Google Pixel 5', 'Android', 46, 1.1, 487, 208, 23, 'Male')
# (172, 173, 'OnePlus 9', 'Android', 153, 2.8, 935, 578, 37, 'Female')
# (173, 174, 'iPhone 12', 'iOS', 368, 6.6, 1817, 1406, 27, 'Female')
# (174, 175, 'Xiaomi Mi 11', 'Android', 51, 1.6, 509, 113, 29, 'Female')
# (175, 176, 'Google Pixel 5', 'Android', 279, 5.2, 1660, 629, 50, 'Female')
# (176, 177, 'Xiaomi Mi 11', 'Android', 255, 5.4, 1738, 826, 21, 'Male')
# (177, 178, 'Samsung Galaxy S21', 'Android', 193, 5.7, 1471, 972, 31, 'Female')
# (178, 179, 'Xiaomi Mi 11', 'Android', 207, 5.7, 1582, 692, 38, 'Male')
# (179, 180, 'iPhone 12', 'iOS', 539, 11.9, 2853, 2007, 55, 'Male')
# (180, 181, 'OnePlus 9', 'Android', 151, 2.4, 1124, 571, 33, 'Male')
# (181, 182, 'Google Pixel 5', 'Android', 474, 6.4, 2109, 1079, 24, 'Male')
# (182, 183, 'iPhone 12', 'iOS', 544, 9.2, 2936, 2416, 47, 'Female')
# (183, 184, 'iPhone 12', 'iOS', 73, 1.2, 308, 275, 39, 'Female')
# (184, 185, 'Xiaomi Mi 11', 'Android', 597, 10.4, 2984, 1564, 34, 'Female')
# (185, 186, 'Google Pixel 5', 'Android', 498, 10.7, 2738, 1995, 42, 'Male')
# (186, 187, 'iPhone 12', 'iOS', 402, 7.8, 2014, 1088, 34, 'Female')
# (187, 188, 'OnePlus 9', 'Android', 75, 1.1, 379, 185, 37, 'Male')
# (188, 189, 'iPhone 12', 'iOS', 130, 2.0, 602, 589, 30, 'Female')
# (189, 190, 'Samsung Galaxy S21', 'Android', 42, 1.1, 402, 265, 32, 'Female')
# (190, 191, 'iPhone 12', 'iOS', 134, 2.2, 917, 423, 23, 'Male')
# (191, 192, 'Google Pixel 5', 'Android', 79, 1.9, 477, 161, 24, 'Male')
# (192, 193, 'iPhone 12', 'iOS', 432, 7.2, 1822, 1127, 59, 'Female')
# (193, 194, 'iPhone 12', 'iOS', 262, 4.1, 1287, 997, 36, 'Male')
# (194, 195, 'Samsung Galaxy S21', 'Android', 473, 6.4, 2109, 1300, 23, 'Female')
# (195, 196, 'Google Pixel 5', 'Android', 202, 4.7, 1512, 659, 45, 'Female')
# (196, 197, 'OnePlus 9', 'Android', 215, 4.4, 1407, 991, 47, 'Male')
# (197, 198, 'OnePlus 9', 'Android', 151, 3.7, 1116, 320, 41, 'Female')
# (198, 199, 'OnePlus 9', 'Android', 80, 1.6, 549, 197, 19, 'Male')
# (199, 200, 'Xiaomi Mi 11', 'Android', 126, 2.8, 971, 431, 35, 'Female')
# (200, 201, 'Samsung Galaxy S21', 'Android', 495, 8.9, 2920, 2252, 31, 'Female')
# (201, 202, 'iPhone 12', 'iOS', 127, 3.7, 1153, 314, 37, 'Female')
# (202, 203, 'Xiaomi Mi 11', 'Android', 88, 1.3, 327, 262, 22, 'Male')
# (203, 204, 'Google Pixel 5', 'Android', 69, 1.6, 463, 146, 27, 'Male')
# (204, 205, 'OnePlus 9', 'Android', 100, 3.3, 961, 433, 25, 'Male')
# (205, 206, 'Xiaomi Mi 11', 'Android', 301, 6.5, 2084, 1421, 29, 'Male')
# (206, 207, 'Google Pixel 5', 'Android', 78, 1.7, 455, 207, 37, 'Female')
# (207, 208, 'Google Pixel 5', 'Android', 163, 3.1, 620, 419, 23, 'Male')
# (208, 209, 'OnePlus 9', 'Android', 539, 9.3, 2606, 1990, 41, 'Male')
# (209, 210, 'Google Pixel 5', 'Android', 278, 4.6, 1385, 823, 40, 'Female')
# (210, 211, 'Samsung Galaxy S21', 'Android', 451, 6.1, 2108, 1434, 25, 'Female')
# (211, 212, 'Samsung Galaxy S21', 'Android', 481, 10.9, 2752, 2017, 18, 'Male')
# (212, 213, 'Samsung Galaxy S21', 'Android', 133, 3.4, 714, 445, 25, 'Male')
# (213, 214, 'Xiaomi Mi 11', 'Android', 41, 1.1, 588, 246, 22, 'Male')
# (214, 215, 'iPhone 12', 'iOS', 152, 3.3, 1175, 461, 42, 'Female')
# (215, 216, 'OnePlus 9', 'Android', 553, 8.4, 2559, 2471, 51, 'Male')
# (216, 217, 'iPhone 12', 'iOS', 402, 6.9, 2282, 1397, 40, 'Male')
# (217, 218, 'OnePlus 9', 'Android', 555, 9.5, 2855, 1565, 24, 'Male')
# (218, 219, 'iPhone 12', 'iOS', 499, 9.6, 2873, 1805, 52, 'Female')
# (219, 220, 'Xiaomi Mi 11', 'Android', 101, 3.2, 603, 417, 43, 'Male')
# (220, 221, 'OnePlus 9', 'Android', 433, 6.8, 2093, 1300, 32, 'Male')
# (221, 222, 'OnePlus 9', 'Android', 133, 2.0, 1007, 417, 32, 'Male')
# (222, 223, 'Xiaomi Mi 11', 'Android', 351, 6.1, 1941, 1290, 21, 'Female')
# (223, 224, 'Samsung Galaxy S21', 'Android', 532, 10.7, 2556, 2148, 53, 'Female')
# (224, 225, 'OnePlus 9', 'Android', 92, 2.5, 690, 563, 27, 'Male')
# (225, 226, 'Xiaomi Mi 11', 'Android', 511, 10.8, 2712, 2438, 59, 'Female')
# (226, 227, 'Xiaomi Mi 11', 'Android', 384, 7.0, 2185, 1376, 59, 'Male')
# (227, 228, 'iPhone 12', 'iOS', 193, 5.2, 1318, 626, 32, 'Female')
# (228, 229, 'Samsung Galaxy S21', 'Android', 132, 3.8, 649, 368, 41, 'Male')
# (229, 230, 'Samsung Galaxy S21', 'Android', 360, 7.3, 1946, 1164, 50, 'Male')
# (230, 231, 'iPhone 12', 'iOS', 159, 2.3, 1083, 526, 38, 'Male')
# (231, 232, 'iPhone 12', 'iOS', 495, 8.9, 2855, 2150, 31, 'Male')
# (232, 233, 'Xiaomi Mi 11', 'Android', 537, 10.0, 2720, 1763, 35, 'Male')
# (233, 234, 'OnePlus 9', 'Android', 129, 3.4, 1059, 580, 36, 'Female')
# (234, 235, 'iPhone 12', 'iOS', 132, 3.8, 636, 529, 53, 'Male')
# (235, 236, 'Xiaomi Mi 11', 'Android', 37, 1.4, 369, 295, 19, 'Female')
# (236, 237, 'Samsung Galaxy S21', 'Android', 524, 8.9, 2549, 1730, 20, 'Female')
# (237, 238, 'OnePlus 9', 'Android', 425, 6.9, 2142, 1130, 19, 'Female')
# (238, 239, 'OnePlus 9', 'Android', 64, 1.7, 585, 107, 53, 'Male')
# (239, 240, 'iPhone 12', 'iOS', 573, 10.8, 2711, 2118, 33, 'Female')
# (240, 241, 'Google Pixel 5', 'Android', 45, 1.7, 302, 191, 57, 'Female')
# (241, 242, 'Xiaomi Mi 11', 'Android', 564, 11.7, 2764, 2133, 37, 'Female')
# (242, 243, 'OnePlus 9', 'Android', 162, 3.5, 761, 338, 51, 'Male')
# (243, 244, 'Samsung Galaxy S21', 'Android', 451, 6.5, 2378, 1341, 44, 'Male')
# (244, 245, 'OnePlus 9', 'Android', 30, 1.3, 479, 253, 35, 'Male')
# (245, 246, 'Samsung Galaxy S21', 'Android', 202, 5.0, 1542, 844, 29, 'Male')
# (246, 247, 'Google Pixel 5', 'Android', 71, 1.5, 590, 257, 33, 'Male')
# (247, 248, 'Google Pixel 5', 'Android', 314, 6.2, 2205, 1066, 19, 'Male')
# (248, 249, 'Xiaomi Mi 11', 'Android', 168, 4.0, 866, 581, 50, 'Female')
# (249, 250, 'Google Pixel 5', 'Android', 75, 1.9, 537, 230, 58, 'Female')
# (250, 251, 'OnePlus 9', 'Android', 42, 1.4, 324, 272, 29, 'Female')
# (251, 252, 'OnePlus 9', 'Android', 441, 7.9, 2332, 1477, 23, 'Female')
# (252, 253, 'Google Pixel 5', 'Android', 523, 10.5, 2460, 1787, 22, 'Male')
# (253, 254, 'Xiaomi Mi 11', 'Android', 100, 2.4, 982, 478, 48, 'Female')
# (254, 255, 'OnePlus 9', 'Android', 52, 1.2, 398, 172, 24, 'Female')
# (255, 256, 'OnePlus 9', 'Android', 397, 7.0, 2352, 1101, 46, 'Female')
# (256, 257, 'Xiaomi Mi 11', 'Android', 424, 7.7, 1863, 1116, 52, 'Male')
# (257, 258, 'Xiaomi Mi 11', 'Android', 272, 5.0, 1655, 686, 19, 'Female')
# (258, 259, 'Xiaomi Mi 11', 'Android', 201, 4.0, 1791, 914, 18, 'Male')
# (259, 260, 'Xiaomi Mi 11', 'Android', 570, 9.0, 2613, 2497, 49, 'Female')
# (260, 261, 'Xiaomi Mi 11', 'Android', 64, 1.3, 490, 151, 43, 'Female')
# (261, 262, 'iPhone 12', 'iOS', 334, 6.6, 2394, 1227, 46, 'Female')
# (262, 263, 'iPhone 12', 'iOS', 518, 9.6, 2954, 2125, 34, 'Female')
# (263, 264, 'Samsung Galaxy S21', 'Android', 70, 1.7, 359, 109, 57, 'Male')
# (264, 265, 'iPhone 12', 'iOS', 334, 6.8, 2000, 1079, 40, 'Female')
# (265, 266, 'Xiaomi Mi 11', 'Android', 563, 8.4, 2849, 1508, 25, 'Male')
# (266, 267, 'iPhone 12', 'iOS', 181, 4.1, 1608, 752, 22, 'Female')
# (267, 268, 'OnePlus 9', 'Android', 584, 9.4, 2766, 2151, 32, 'Male')
# (268, 269, 'Samsung Galaxy S21', 'Android', 208, 4.7, 1642, 861, 55, 'Male')
# (269, 270, 'Samsung Galaxy S21', 'Android', 381, 6.6, 2160, 1450, 20, 'Male')
# (270, 271, 'Xiaomi Mi 11', 'Android', 426, 6.5, 1969, 1266, 53, 'Female')
# (271, 272, 'OnePlus 9', 'Android', 284, 4.2, 1360, 888, 51, 'Male')
# (272, 273, 'Google Pixel 5', 'Android', 105, 2.2, 1002, 453, 31, 'Female')
# (273, 274, 'Google Pixel 5', 'Android', 179, 2.3, 1014, 588, 38, 'Male')
# (274, 275, 'iPhone 12', 'iOS', 122, 2.6, 639, 568, 35, 'Male')
# (275, 276, 'OnePlus 9', 'Android', 501, 11.9, 2702, 1738, 49, 'Male')
# (276, 277, 'Xiaomi Mi 11', 'Android', 269, 5.9, 1666, 629, 32, 'Female')
# (277, 278, 'Google Pixel 5', 'Android', 230, 4.4, 1607, 878, 54, 'Male')
# (278, 279, 'Xiaomi Mi 11', 'Android', 85, 1.6, 417, 122, 47, 'Male')
# (279, 280, 'Samsung Galaxy S21', 'Android', 411, 7.8, 2029, 1136, 33, 'Female')
# (280, 281, 'Samsung Galaxy S21', 'Android', 73, 1.7, 403, 163, 51, 'Male')
# (281, 282, 'Xiaomi Mi 11', 'Android', 39, 1.7, 530, 268, 26, 'Female')
# (282, 283, 'iPhone 12', 'iOS', 386, 7.7, 2114, 1209, 51, 'Male')
# (283, 284, 'Google Pixel 5', 'Android', 49, 1.3, 542, 169, 54, 'Female')
# (284, 285, 'Google Pixel 5', 'Android', 411, 6.9, 1820, 1024, 43, 'Male')
# (285, 286, 'OnePlus 9', 'Android', 534, 10.8, 2805, 1538, 37, 'Male')
# (286, 287, 'Samsung Galaxy S21', 'Android', 314, 7.4, 2136, 1376, 47, 'Female')
# (287, 288, 'Xiaomi Mi 11', 'Android', 211, 4.0, 1519, 811, 29, 'Female')
# (288, 289, 'OnePlus 9', 'Android', 121, 3.7, 619, 473, 47, 'Male')
# (289, 290, 'Google Pixel 5', 'Android', 84, 1.2, 415, 146, 50, 'Male')
# (290, 291, 'OnePlus 9', 'Android', 448, 7.6, 2199, 1047, 28, 'Male')
# (291, 292, 'Google Pixel 5', 'Android', 55, 1.6, 360, 149, 30, 'Male')
# (292, 293, 'Google Pixel 5', 'Android', 59, 1.8, 497, 208, 36, 'Female')
# (293, 294, 'Xiaomi Mi 11', 'Android', 226, 4.5, 1781, 649, 27, 'Female')
# (294, 295, 'Samsung Galaxy S21', 'Android', 580, 8.5, 2660, 1795, 52, 'Male')
# (295, 296, 'OnePlus 9', 'Android', 65, 1.8, 481, 130, 41, 'Male')
# (296, 297, 'OnePlus 9', 'Android', 458, 6.6, 2214, 1163, 31, 'Female')
# (297, 298, 'iPhone 12', 'iOS', 170, 2.7, 805, 344, 53, 'Female')
# (298, 299, 'iPhone 12', 'iOS', 264, 5.2, 1641, 778, 44, 'Male')
# (299, 300, 'Xiaomi Mi 11', 'Android', 122, 3.3, 748, 499, 59, 'Female')
# (300, 301, 'Xiaomi Mi 11', 'Android', 420, 6.5, 2113, 1314, 35, 'Male')
# (301, 302, 'iPhone 12', 'iOS', 267, 4.4, 1505, 971, 38, 'Female')
# (302, 303, 'iPhone 12', 'iOS', 469, 6.0, 2290, 1086, 34, 'Female')
# (303, 304, 'iPhone 12', 'iOS', 541, 11.4, 2443, 1923, 34, 'Female')
# (304, 305, 'iPhone 12', 'iOS', 155, 2.9, 1117, 322, 19, 'Female')
# (305, 306, 'OnePlus 9', 'Android', 106, 2.8, 686, 594, 27, 'Male')
# (306, 307, 'OnePlus 9', 'Android', 243, 5.0, 1232, 877, 43, 'Male')
# (307, 308, 'OnePlus 9', 'Android', 410, 7.5, 2176, 1213, 45, 'Female')
# (308, 309, 'iPhone 12', 'iOS', 285, 5.1, 1226, 666, 20, 'Female')
# (309, 310, 'OnePlus 9', 'Android', 397, 6.8, 2027, 1167, 40, 'Male')
# (310, 311, 'Samsung Galaxy S21', 'Android', 230, 4.2, 1507, 868, 25, 'Female')
# (311, 312, 'iPhone 12', 'iOS', 341, 7.2, 2397, 1055, 32, 'Female')
# (312, 313, 'Google Pixel 5', 'Android', 132, 2.9, 1054, 563, 20, 'Male')
# (313, 314, 'Xiaomi Mi 11', 'Android', 130, 3.0, 820, 308, 49, 'Female')
# (314, 315, 'iPhone 12', 'iOS', 281, 4.9, 1566, 632, 29, 'Male')
# (315, 316, 'OnePlus 9', 'Android', 74, 2.0, 320, 103, 55, 'Female')
# (316, 317, 'OnePlus 9', 'Android', 299, 4.3, 1737, 953, 42, 'Female')
# (317, 318, 'Google Pixel 5', 'Android', 116, 2.2, 827, 434, 28, 'Female')
# (318, 319, 'OnePlus 9', 'Android', 408, 6.6, 2026, 1076, 47, 'Female')
# (319, 320, 'Google Pixel 5', 'Android', 508, 11.3, 2590, 2481, 51, 'Male')
# (320, 321, 'iPhone 12', 'iOS', 227, 4.4, 1275, 984, 22, 'Female')
# (321, 322, 'Google Pixel 5', 'Android', 274, 6.0, 1489, 666, 57, 'Female')
# (322, 323, 'Google Pixel 5', 'Android', 347, 6.3, 2001, 1456, 21, 'Female')
# (323, 324, 'Xiaomi Mi 11', 'Android', 76, 1.3, 490, 156, 31, 'Female')
# (324, 325, 'iPhone 12', 'iOS', 445, 7.5, 2007, 1115, 23, 'Male')
# (325, 326, 'OnePlus 9', 'Android', 203, 4.3, 1554, 638, 25, 'Female')
# (326, 327, 'Samsung Galaxy S21', 'Android', 199, 6.0, 1707, 881, 55, 'Male')
# (327, 328, 'OnePlus 9', 'Android', 48, 2.0, 574, 127, 24, 'Female')
# (328, 329, 'OnePlus 9', 'Android', 88, 1.6, 420, 274, 31, 'Female')
# (329, 330, 'iPhone 12', 'iOS', 541, 8.3, 2865, 1820, 42, 'Female')
# (330, 331, 'Google Pixel 5', 'Android', 233, 4.6, 1534, 796, 21, 'Female')
# (331, 332, 'iPhone 12', 'iOS', 176, 3.8, 727, 362, 47, 'Female')
# (332, 333, 'OnePlus 9', 'Android', 191, 6.0, 1762, 904, 54, 'Male')
# (333, 334, 'Google Pixel 5', 'Android', 461, 7.5, 2001, 1324, 34, 'Female')
# (334, 335, 'Samsung Galaxy S21', 'Android', 37, 1.5, 375, 246, 46, 'Female')
# (335, 336, 'OnePlus 9', 'Android', 531, 9.8, 2905, 1632, 45, 'Female')
# (336, 337, 'Samsung Galaxy S21', 'Android', 473, 7.9, 2292, 1472, 44, 'Male')
# (337, 338, 'Samsung Galaxy S21', 'Android', 30, 1.3, 561, 252, 34, 'Male')
# (338, 339, 'iPhone 12', 'iOS', 306, 6.1, 2267, 1449, 46, 'Male')
# (339, 340, 'iPhone 12', 'iOS', 64, 1.2, 590, 155, 30, 'Male')
# (340, 341, 'iPhone 12', 'iOS', 75, 1.0, 435, 223, 43, 'Male')
# (341, 342, 'iPhone 12', 'iOS', 597, 10.3, 2718, 1863, 26, 'Female')
# (342, 343, 'iPhone 12', 'iOS', 529, 10.5, 2971, 1683, 56, 'Male')
# (343, 344, 'iPhone 12', 'iOS', 290, 6.0, 1533, 645, 57, 'Female')
# (344, 345, 'iPhone 12', 'iOS', 256, 5.8, 1309, 840, 43, 'Male')
# (345, 346, 'iPhone 12', 'iOS', 308, 7.7, 1974, 1431, 37, 'Female')
# (346, 347, 'OnePlus 9', 'Android', 156, 3.3, 1020, 447, 57, 'Female')
# (347, 348, 'Samsung Galaxy S21', 'Android', 62, 1.4, 542, 266, 46, 'Male')
# (348, 349, 'Google Pixel 5', 'Android', 156, 3.8, 866, 510, 26, 'Male')
# (349, 350, 'Samsung Galaxy S21', 'Android', 303, 7.4, 2314, 1387, 34, 'Male')
# (350, 351, 'Samsung Galaxy S21', 'Android', 463, 6.9, 2111, 1463, 54, 'Male')
# (351, 352, 'Google Pixel 5', 'Android', 60, 1.5, 593, 281, 35, 'Female')
# (352, 353, 'Google Pixel 5', 'Android', 225, 4.6, 1230, 954, 20, 'Female')
# (353, 354, 'Samsung Galaxy S21', 'Android', 379, 7.5, 1823, 1075, 53, 'Female')
# (354, 355, 'OnePlus 9', 'Android', 53, 1.4, 455, 106, 54, 'Female')
# (355, 356, 'Samsung Galaxy S21', 'Android', 30, 1.9, 574, 287, 45, 'Male')
# (356, 357, 'iPhone 12', 'iOS', 291, 4.1, 1326, 905, 55, 'Female')
# (357, 358, 'iPhone 12', 'iOS', 488, 9.5, 2840, 1986, 48, 'Female')
# (358, 359, 'Google Pixel 5', 'Android', 74, 2.0, 366, 253, 44, 'Female')
# (359, 360, 'Samsung Galaxy S21', 'Android', 230, 4.6, 1325, 845, 54, 'Female')
# (360, 361, 'Samsung Galaxy S21', 'Android', 517, 11.8, 2435, 2208, 26, 'Male')
# (361, 362, 'OnePlus 9', 'Android', 557, 10.4, 2900, 1609, 22, 'Male')
# (362, 363, 'Xiaomi Mi 11', 'Android', 78, 1.5, 341, 259, 38, 'Female')
# (363, 364, 'iPhone 12', 'iOS', 321, 7.9, 2159, 1499, 45, 'Male')
# (364, 365, 'Xiaomi Mi 11', 'Android', 579, 8.6, 2539, 1935, 34, 'Male')
# (365, 366, 'OnePlus 9', 'Android', 382, 7.2, 1965, 1341, 22, 'Male')
# (366, 367, 'Xiaomi Mi 11', 'Android', 516, 11.6, 2464, 1767, 29, 'Female')
# (367, 368, 'OnePlus 9', 'Android', 598, 11.2, 2876, 2477, 58, 'Female')
# (368, 369, 'OnePlus 9', 'Android', 102, 3.9, 747, 408, 49, 'Female')
# (369, 370, 'iPhone 12', 'iOS', 165, 2.4, 816, 503, 34, 'Male')
# (370, 371, 'iPhone 12', 'iOS', 558, 9.8, 2765, 1548, 25, 'Female')
# (371, 372, 'Google Pixel 5', 'Android', 561, 10.6, 2547, 1823, 22, 'Male')
# (372, 373, 'Samsung Galaxy S21', 'Android', 511, 10.9, 2514, 2335, 59, 'Female')
# (373, 374, 'Google Pixel 5', 'Android', 560, 11.3, 2947, 1663, 25, 'Female')
# (374, 375, 'OnePlus 9', 'Android', 69, 1.3, 434, 164, 42, 'Male')
# (375, 376, 'OnePlus 9', 'Android', 44, 1.1, 531, 232, 26, 'Male')
# (376, 377, 'iPhone 12', 'iOS', 65, 1.7, 490, 122, 51, 'Female')
# (377, 378, 'Google Pixel 5', 'Android', 458, 6.0, 1875, 1072, 31, 'Female')
# (378, 379, 'Samsung Galaxy S21', 'Android', 525, 10.8, 2445, 1623, 57, 'Male')
# (379, 380, 'OnePlus 9', 'Android', 106, 3.0, 922, 313, 51, 'Male')
# (380, 381, 'iPhone 12', 'iOS', 188, 4.6, 1767, 653, 34, 'Male')
# (381, 382, 'iPhone 12', 'iOS', 493, 10.4, 2453, 1813, 39, 'Male')
# (382, 383, 'OnePlus 9', 'Android', 84, 1.5, 373, 299, 37, 'Female')
# (383, 384, 'OnePlus 9', 'Android', 104, 2.9, 653, 322, 30, 'Male')
# (384, 385, 'Samsung Galaxy S21', 'Android', 102, 3.0, 890, 548, 28, 'Male')
# (385, 386, 'iPhone 12', 'iOS', 349, 6.6, 2041, 1096, 40, 'Female')
# (386, 387, 'OnePlus 9', 'Android', 98, 2.0, 925, 457, 28, 'Male')
# (387, 388, 'Samsung Galaxy S21', 'Android', 72, 1.3, 461, 199, 32, 'Male')
# (388, 389, 'Xiaomi Mi 11', 'Android', 563, 11.6, 2968, 2191, 34, 'Female')
# (389, 390, 'Xiaomi Mi 11', 'Android', 119, 2.8, 775, 313, 50, 'Female')
# (390, 391, 'OnePlus 9', 'Android', 311, 7.9, 2231, 1021, 36, 'Male')
# (391, 392, 'OnePlus 9', 'Android', 337, 6.1, 1901, 1359, 58, 'Male')
# (392, 393, 'Samsung Galaxy S21', 'Android', 168, 3.5, 1055, 313, 54, 'Male')
# (393, 394, 'iPhone 12', 'iOS', 331, 7.4, 2129, 1459, 53, 'Male')
# (394, 395, 'Google Pixel 5', 'Android', 589, 9.2, 2663, 1774, 45, 'Female')
# (395, 396, 'Xiaomi Mi 11', 'Android', 472, 6.8, 2288, 1356, 52, 'Male')
# (396, 397, 'Xiaomi Mi 11', 'Android', 78, 1.1, 437, 143, 27, 'Female')
# (397, 398, 'iPhone 12', 'iOS', 517, 11.6, 2798, 2175, 20, 'Male')
# (398, 399, 'OnePlus 9', 'Android', 41, 1.6, 323, 221, 43, 'Female')
# (399, 400, 'OnePlus 9', 'Android', 49, 1.5, 571, 203, 29, 'Male')
# (400, 401, 'Xiaomi Mi 11', 'Android', 522, 11.1, 2821, 1891, 42, 'Male')
# (401, 402, 'Google Pixel 5', 'Android', 97, 2.7, 612, 508, 53, 'Male')
# (402, 403, 'iPhone 12', 'iOS', 411, 7.4, 1960, 1264, 40, 'Male')
# (403, 404, 'Samsung Galaxy S21', 'Android', 566, 8.6, 2595, 1657, 51, 'Female')
# (404, 405, 'iPhone 12', 'iOS', 559, 8.2, 2618, 2102, 22, 'Female')
# (405, 406, 'Google Pixel 5', 'Android', 478, 7.3, 2340, 1017, 43, 'Female')
# (406, 407, 'Xiaomi Mi 11', 'Android', 147, 3.2, 994, 567, 25, 'Female')
# (407, 408, 'OnePlus 9', 'Android', 395, 7.3, 2291, 1049, 55, 'Female')
# (408, 409, 'Samsung Galaxy S21', 'Android', 357, 7.8, 2289, 1242, 22, 'Female')
# (409, 410, 'Google Pixel 5', 'Android', 405, 6.9, 2366, 1434, 51, 'Male')
# (410, 411, 'Samsung Galaxy S21', 'Android', 501, 11.8, 2790, 2074, 31, 'Female')
# (411, 412, 'Xiaomi Mi 11', 'Android', 575, 8.2, 2918, 1928, 50, 'Male')
# (412, 413, 'OnePlus 9', 'Android', 257, 5.1, 1692, 769, 52, 'Female')
# (413, 414, 'iPhone 12', 'iOS', 270, 5.0, 1532, 957, 35, 'Male')
# (414, 415, 'Google Pixel 5', 'Android', 116, 2.0, 1171, 573, 33, 'Female')
# (415, 416, 'iPhone 12', 'iOS', 98, 2.3, 608, 394, 56, 'Male')
# (416, 417, 'Xiaomi Mi 11', 'Android', 264, 5.1, 1293, 737, 27, 'Female')
# (417, 418, 'Samsung Galaxy S21', 'Android', 572, 11.7, 2655, 2481, 57, 'Female')
# (418, 419, 'Xiaomi Mi 11', 'Android', 202, 4.9, 1549, 964, 27, 'Female')
# (419, 420, 'iPhone 12', 'iOS', 83, 1.4, 454, 228, 46, 'Male')
# (420, 421, 'iPhone 12', 'iOS', 32, 1.4, 416, 198, 56, 'Male')
# (421, 422, 'iPhone 12', 'iOS', 168, 3.2, 716, 414, 43, 'Male')
# (422, 423, 'iPhone 12', 'iOS', 416, 6.1, 2115, 1041, 22, 'Female')
# (423, 424, 'Xiaomi Mi 11', 'Android', 46, 1.1, 536, 167, 28, 'Female')
# (424, 425, 'OnePlus 9', 'Android', 201, 5.0, 1482, 709, 24, 'Male')
# (425, 426, 'Samsung Galaxy S21', 'Android', 130, 2.8, 1062, 579, 37, 'Male')
# (426, 427, 'OnePlus 9', 'Android', 98, 2.4, 747, 403, 44, 'Female')
# (427, 428, 'OnePlus 9', 'Android', 105, 3.8, 967, 489, 51, 'Male')
# (428, 429, 'Xiaomi Mi 11', 'Android', 94, 2.3, 1033, 369, 58, 'Male')
# (429, 430, 'Xiaomi Mi 11', 'Android', 540, 10.1, 2757, 2180, 37, 'Male')
# (430, 431, 'iPhone 12', 'iOS', 266, 5.5, 1238, 839, 22, 'Male')
# (431, 432, 'iPhone 12', 'iOS', 140, 3.8, 1137, 506, 53, 'Male')
# (432, 433, 'Google Pixel 5', 'Android', 534, 10.4, 2672, 1702, 51, 'Male')
# (433, 434, 'OnePlus 9', 'Android', 46, 2.0, 309, 116, 42, 'Male')
# (434, 435, 'iPhone 12', 'iOS', 581, 8.4, 2591, 2304, 58, 'Male')
# (435, 436, 'Xiaomi Mi 11', 'Android', 105, 3.4, 798, 467, 34, 'Female')
# (436, 437, 'OnePlus 9', 'Android', 221, 4.4, 1341, 862, 20, 'Male')
# (437, 438, 'iPhone 12', 'iOS', 41, 1.7, 408, 291, 34, 'Male')
# (438, 439, 'OnePlus 9', 'Android', 105, 3.0, 728, 343, 52, 'Female')
# (439, 440, 'Google Pixel 5', 'Android', 123, 3.9, 915, 468, 18, 'Male')
# (440, 441, 'Google Pixel 5', 'Android', 260, 5.7, 1725, 920, 36, 'Female')
# (441, 442, 'Samsung Galaxy S21', 'Android', 223, 5.7, 1295, 751, 39, 'Male')
# (442, 443, 'Google Pixel 5', 'Android', 66, 1.1, 505, 218, 33, 'Male')
# (443, 444, 'iPhone 12', 'iOS', 231, 4.0, 1664, 724, 29, 'Female')
# (444, 445, 'iPhone 12', 'iOS', 555, 8.8, 2540, 2402, 22, 'Male')
# (445, 446, 'Samsung Galaxy S21', 'Android', 378, 7.2, 1859, 1318, 58, 'Male')
# (446, 447, 'OnePlus 9', 'Android', 546, 8.8, 2852, 1641, 24, 'Male')
# (447, 448, 'Samsung Galaxy S21', 'Android', 234, 5.2, 1604, 919, 58, 'Male')
# (448, 449, 'Samsung Galaxy S21', 'Android', 152, 3.0, 617, 306, 22, 'Female')
# (449, 450, 'Google Pixel 5', 'Android', 34, 1.2, 518, 170, 20, 'Female')
# (450, 451, 'Samsung Galaxy S21', 'Android', 179, 3.5, 1114, 466, 56, 'Male')
# (451, 452, 'OnePlus 9', 'Android', 591, 11.8, 2953, 1903, 52, 'Male')
# (452, 453, 'Samsung Galaxy S21', 'Android', 120, 3.3, 734, 583, 26, 'Male')
# (453, 454, 'Google Pixel 5', 'Android', 88, 1.3, 557, 164, 43, 'Male')
# (454, 455, 'iPhone 12', 'iOS', 143, 3.9, 1160, 398, 45, 'Male')
# (455, 456, 'iPhone 12', 'iOS', 74, 1.6, 436, 182, 27, 'Female')
# (456, 457, 'iPhone 12', 'iOS', 74, 1.6, 587, 275, 27, 'Female')
# (457, 458, 'OnePlus 9', 'Android', 234, 4.7, 1707, 871, 46, 'Male')
# (458, 459, 'iPhone 12', 'iOS', 56, 1.0, 547, 142, 58, 'Female')
# (459, 460, 'OnePlus 9', 'Android', 174, 2.4, 639, 545, 50, 'Male')
# (460, 461, 'Samsung Galaxy S21', 'Android', 523, 9.0, 2696, 1561, 20, 'Female')
# (461, 462, 'Samsung Galaxy S21', 'Android', 123, 3.3, 938, 438, 55, 'Male')
# (462, 463, 'Samsung Galaxy S21', 'Android', 216, 5.9, 1789, 987, 55, 'Male')
# (463, 464, 'iPhone 12', 'iOS', 290, 4.6, 1694, 809, 23, 'Male')
# (464, 465, 'Xiaomi Mi 11', 'Android', 68, 1.3, 583, 281, 26, 'Female')
# (465, 466, 'OnePlus 9', 'Android', 265, 4.8, 1770, 723, 55, 'Female')
# (466, 467, 'Samsung Galaxy S21', 'Android', 414, 7.3, 2349, 1092, 51, 'Male')
# (467, 468, 'Google Pixel 5', 'Android', 238, 4.0, 1414, 661, 41, 'Female')
# (468, 469, 'Xiaomi Mi 11', 'Android', 429, 7.5, 1921, 1102, 46, 'Male')
# (469, 470, 'Xiaomi Mi 11', 'Android', 39, 1.9, 541, 294, 37, 'Male')
# (470, 471, 'Samsung Galaxy S21', 'Android', 248, 4.6, 1396, 883, 40, 'Male')
# (471, 472, 'Xiaomi Mi 11', 'Android', 541, 9.4, 2452, 1811, 53, 'Female')
# (472, 473, 'Xiaomi Mi 11', 'Android', 139, 3.0, 697, 513, 26, 'Female')
# (473, 474, 'iPhone 12', 'iOS', 289, 5.0, 1625, 687, 29, 'Male')
# (474, 475, 'Xiaomi Mi 11', 'Android', 210, 4.9, 1657, 765, 49, 'Female')
# (475, 476, 'Samsung Galaxy S21', 'Android', 412, 6.2, 2201, 1085, 54, 'Female')
# (476, 477, 'Google Pixel 5', 'Android', 318, 6.6, 2089, 1126, 49, 'Female')
# (477, 478, 'iPhone 12', 'iOS', 258, 4.2, 1315, 762, 59, 'Female')
# (478, 479, 'OnePlus 9', 'Android', 258, 4.3, 1759, 718, 41, 'Female')
# (479, 480, 'Samsung Galaxy S21', 'Android', 189, 4.8, 1681, 795, 57, 'Male')
# (480, 481, 'iPhone 12', 'iOS', 155, 2.4, 954, 441, 51, 'Male')
# (481, 482, 'Samsung Galaxy S21', 'Android', 528, 10.4, 2717, 2140, 34, 'Male')
# (482, 483, 'iPhone 12', 'iOS', 549, 11.1, 2851, 1814, 56, 'Male')
# (483, 484, 'Xiaomi Mi 11', 'Android', 78, 1.6, 470, 230, 49, 'Female')
# (484, 485, 'iPhone 12', 'iOS', 444, 6.0, 1873, 1093, 39, 'Female')
# (485, 486, 'Xiaomi Mi 11', 'Android', 80, 1.1, 417, 298, 36, 'Male')
# (486, 487, 'iPhone 12', 'iOS', 131, 3.8, 739, 330, 57, 'Female')
# (487, 488, 'iPhone 12', 'iOS', 228, 4.4, 1734, 804, 57, 'Female')
# (488, 489, 'Xiaomi Mi 11', 'Android', 416, 7.3, 1882, 1333, 32, 'Female')
# (489, 490, 'Google Pixel 5', 'Android', 586, 9.3, 2403, 2332, 21, 'Male')
# (490, 491, 'Google Pixel 5', 'Android', 416, 6.1, 2279, 1096, 47, 'Male')
# (491, 492, 'iPhone 12', 'iOS', 152, 3.7, 948, 507, 53, 'Female')
# (492, 493, 'Xiaomi Mi 11', 'Android', 87, 1.5, 594, 198, 36, 'Female')
# (493, 494, 'OnePlus 9', 'Android', 329, 6.8, 1892, 1383, 23, 'Male')
# (494, 495, 'Samsung Galaxy S21', 'Android', 107, 2.5, 1176, 545, 29, 'Female')
# (495, 496, 'Google Pixel 5', 'Android', 493, 10.9, 2928, 2116, 57, 'Male')
# (496, 497, 'iPhone 12', 'iOS', 182, 4.8, 1500, 807, 43, 'Female')
# (497, 498, 'iPhone 12', 'iOS', 102, 2.9, 918, 362, 20, 'Female')
# (498, 499, 'Google Pixel 5', 'Android', 274, 4.5, 1356, 869, 53, 'Male')
# (499, 500, 'iPhone 12', 'iOS', 143, 3.6, 988, 504, 45, 'Female')
# (500, 501, 'Google Pixel 5', 'Android', 66, 1.3, 369, 195, 32, 'Male')
# (501, 502, 'Xiaomi Mi 11', 'Android', 420, 7.7, 2017, 1187, 24, 'Female')
# (502, 503, 'Xiaomi Mi 11', 'Android', 582, 8.4, 2664, 2493, 55, 'Female')
# (503, 504, 'Google Pixel 5', 'Android', 200, 5.8, 1291, 965, 52, 'Male')
# (504, 505, 'Google Pixel 5', 'Android', 493, 8.5, 2859, 2450, 47, 'Male')
# (505, 506, 'Samsung Galaxy S21', 'Android', 348, 6.6, 2398, 1415, 49, 'Female')
# (506, 507, 'Xiaomi Mi 11', 'Android', 238, 5.1, 1408, 941, 27, 'Male')
# (507, 508, 'Xiaomi Mi 11', 'Android', 33, 2.0, 318, 173, 42, 'Female')
# (508, 509, 'Google Pixel 5', 'Android', 267, 5.9, 1740, 791, 22, 'Male')
# (509, 510, 'iPhone 12', 'iOS', 492, 10.0, 2513, 1968, 31, 'Male')
# (510, 511, 'Google Pixel 5', 'Android', 241, 5.3, 1767, 976, 38, 'Female')
# (511, 512, 'Samsung Galaxy S21', 'Android', 567, 10.8, 2911, 1682, 39, 'Male')
# (512, 513, 'Samsung Galaxy S21', 'Android', 36, 1.6, 442, 249, 34, 'Male')
# (513, 514, 'OnePlus 9', 'Android', 110, 3.4, 975, 507, 57, 'Female')
# (514, 515, 'Samsung Galaxy S21', 'Android', 466, 7.1, 1984, 1461, 54, 'Male')
# (515, 516, 'OnePlus 9', 'Android', 126, 2.2, 1187, 599, 25, 'Male')
# (516, 517, 'Xiaomi Mi 11', 'Android', 120, 3.8, 940, 535, 44, 'Male')
# (517, 518, 'iPhone 12', 'iOS', 64, 1.2, 592, 218, 25, 'Male')
# (518, 519, 'OnePlus 9', 'Android', 574, 8.5, 2780, 1809, 34, 'Female')
# (519, 520, 'OnePlus 9', 'Android', 119, 2.2, 1123, 371, 51, 'Male')
# (520, 521, 'OnePlus 9', 'Android', 350, 6.5, 2364, 1485, 20, 'Male')
# (521, 522, 'Google Pixel 5', 'Android', 69, 1.1, 535, 250, 25, 'Male')
# (522, 523, 'Xiaomi Mi 11', 'Android', 438, 6.5, 1849, 1125, 49, 'Female')
# (523, 524, 'Samsung Galaxy S21', 'Android', 506, 11.2, 2623, 2460, 48, 'Male')
# (524, 525, 'Samsung Galaxy S21', 'Android', 272, 5.2, 1390, 792, 57, 'Female')
# (525, 526, 'Samsung Galaxy S21', 'Android', 224, 4.5, 1646, 665, 59, 'Male')
# (526, 527, 'Google Pixel 5', 'Android', 99, 2.4, 689, 318, 29, 'Female')
# (527, 528, 'iPhone 12', 'iOS', 44, 1.2, 466, 131, 57, 'Female')
# (528, 529, 'Google Pixel 5', 'Android', 175, 3.0, 801, 338, 24, 'Male')
# (529, 530, 'Google Pixel 5', 'Android', 228, 4.8, 1639, 796, 42, 'Female')
# (530, 531, 'Xiaomi Mi 11', 'Android', 589, 11.8, 2629, 2479, 43, 'Female')
# (531, 532, 'OnePlus 9', 'Android', 339, 7.9, 1987, 1191, 47, 'Male')
# (532, 533, 'iPhone 12', 'iOS', 431, 6.4, 2206, 1200, 23, 'Female')
# (533, 534, 'Xiaomi Mi 11', 'Android', 190, 4.7, 1276, 915, 22, 'Female')
# (534, 535, 'OnePlus 9', 'Android', 389, 6.1, 2087, 1383, 30, 'Male')
# (535, 536, 'Samsung Galaxy S21', 'Android', 139, 3.3, 937, 573, 25, 'Female')
# (536, 537, 'Samsung Galaxy S21', 'Android', 289, 5.9, 1528, 915, 30, 'Male')
# (537, 538, 'Samsung Galaxy S21', 'Android', 593, 11.1, 2672, 2258, 34, 'Female')
# (538, 539, 'Google Pixel 5', 'Android', 576, 9.5, 2638, 2281, 38, 'Female')
# (539, 540, 'OnePlus 9', 'Android', 592, 9.4, 2867, 1701, 27, 'Female')
# (540, 541, 'iPhone 12', 'iOS', 567, 10.5, 2817, 2194, 52, 'Male')
# (541, 542, 'iPhone 12', 'iOS', 170, 2.5, 740, 537, 25, 'Female')
# (542, 543, 'Google Pixel 5', 'Android', 242, 5.4, 1307, 642, 28, 'Male')
# (543, 544, 'Samsung Galaxy S21', 'Android', 275, 5.5, 1616, 656, 55, 'Male')
# (544, 545, 'Google Pixel 5', 'Android', 544, 9.7, 2633, 1727, 28, 'Female')
# (545, 546, 'OnePlus 9', 'Android', 50, 2.0, 362, 182, 34, 'Female')
# (546, 547, 'OnePlus 9', 'Android', 236, 4.6, 1750, 971, 21, 'Female')
# (547, 548, 'iPhone 12', 'iOS', 139, 2.6, 658, 358, 58, 'Female')
# (548, 549, 'Google Pixel 5', 'Android', 383, 6.6, 2155, 1360, 45, 'Male')
# (549, 550, 'Samsung Galaxy S21', 'Android', 172, 4.0, 1047, 508, 21, 'Female')
# (550, 551, 'Xiaomi Mi 11', 'Android', 455, 6.2, 1984, 1287, 42, 'Male')
# (551, 552, 'Samsung Galaxy S21', 'Android', 157, 2.5, 1110, 373, 37, 'Female')
# (552, 553, 'iPhone 12', 'iOS', 173, 3.8, 605, 583, 32, 'Male')
# (553, 554, 'Samsung Galaxy S21', 'Android', 405, 7.3, 2082, 1162, 37, 'Female')
# (554, 555, 'iPhone 12', 'iOS', 387, 6.6, 2168, 1246, 19, 'Female')
# (555, 556, 'Xiaomi Mi 11', 'Android', 201, 4.9, 1633, 972, 32, 'Female')
# (556, 557, 'iPhone 12', 'iOS', 142, 3.5, 625, 370, 40, 'Female')
# (557, 558, 'Samsung Galaxy S21', 'Android', 198, 4.2, 1392, 640, 27, 'Male')
# (558, 559, 'Google Pixel 5', 'Android', 361, 7.6, 2037, 1056, 55, 'Male')
# (559, 560, 'OnePlus 9', 'Android', 553, 11.6, 2914, 1860, 47, 'Male')
# (560, 561, 'Samsung Galaxy S21', 'Android', 408, 6.2, 2245, 1103, 38, 'Female')
# (561, 562, 'Xiaomi Mi 11', 'Android', 121, 2.1, 1188, 578, 18, 'Male')
# (562, 563, 'Google Pixel 5', 'Android', 71, 1.4, 508, 265, 33, 'Female')
# (563, 564, 'iPhone 12', 'iOS', 46, 1.6, 440, 265, 31, 'Male')
# (564, 565, 'Xiaomi Mi 11', 'Android', 290, 4.4, 1272, 910, 44, 'Male')
# (565, 566, 'Samsung Galaxy S21', 'Android', 60, 1.3, 462, 296, 40, 'Male')
# (566, 567, 'Google Pixel 5', 'Android', 116, 3.9, 1132, 498, 35, 'Female')
# (567, 568, 'OnePlus 9', 'Android', 86, 1.7, 312, 227, 32, 'Male')
# (568, 569, 'Google Pixel 5', 'Android', 291, 5.3, 1537, 700, 49, 'Female')
# (569, 570, 'Google Pixel 5', 'Android', 404, 6.6, 2181, 1327, 18, 'Male')
# (570, 571, 'OnePlus 9', 'Android', 441, 7.1, 1928, 1421, 57, 'Male')
# (571, 572, 'Google Pixel 5', 'Android', 444, 6.1, 2229, 1194, 25, 'Female')
# (572, 573, 'OnePlus 9', 'Android', 211, 5.9, 1757, 864, 56, 'Female')
# (573, 574, 'Samsung Galaxy S21', 'Android', 537, 9.1, 2858, 2158, 22, 'Male')
# (574, 575, 'Xiaomi Mi 11', 'Android', 519, 10.9, 2571, 2163, 47, 'Female')
# (575, 576, 'Samsung Galaxy S21', 'Android', 94, 3.5, 606, 446, 49, 'Male')
# (576, 577, 'Google Pixel 5', 'Android', 554, 10.3, 2776, 1606, 34, 'Female')
# (577, 578, 'iPhone 12', 'iOS', 381, 7.5, 2216, 1291, 37, 'Female')
# (578, 579, 'OnePlus 9', 'Android', 257, 6.0, 1715, 916, 40, 'Female')
# (579, 580, 'Samsung Galaxy S21', 'Android', 47, 1.1, 532, 122, 36, 'Male')
# (580, 581, 'iPhone 12', 'iOS', 527, 10.0, 2430, 1737, 27, 'Female')
# (581, 582, 'Samsung Galaxy S21', 'Android', 148, 2.7, 625, 416, 27, 'Male')
# (582, 583, 'iPhone 12', 'iOS', 191, 5.7, 1414, 991, 19, 'Female')
# (583, 584, 'Google Pixel 5', 'Android', 71, 1.9, 571, 117, 43, 'Female')
# (584, 585, 'OnePlus 9', 'Android', 73, 1.3, 538, 175, 30, 'Female')
# (585, 586, 'OnePlus 9', 'Android', 149, 3.1, 1191, 563, 29, 'Male')
# (586, 587, 'Xiaomi Mi 11', 'Android', 197, 4.4, 1665, 608, 43, 'Female')
# (587, 588, 'Samsung Galaxy S21', 'Android', 328, 6.1, 1975, 1101, 24, 'Male')
# (588, 589, 'OnePlus 9', 'Android', 424, 7.5, 1995, 1228, 36, 'Male')
# (589, 590, 'Samsung Galaxy S21', 'Android', 111, 3.6, 627, 464, 39, 'Female')
# (590, 591, 'Samsung Galaxy S21', 'Android', 159, 3.7, 630, 575, 30, 'Male')
# (591, 592, 'Google Pixel 5', 'Android', 580, 11.5, 2767, 2341, 36, 'Female')
# (592, 593, 'Samsung Galaxy S21', 'Android', 379, 7.7, 1809, 1050, 22, 'Female')
# (593, 594, 'Samsung Galaxy S21', 'Android', 217, 4.2, 1500, 677, 26, 'Female')
# (594, 595, 'Xiaomi Mi 11', 'Android', 447, 6.3, 1959, 1441, 48, 'Male')
# (595, 596, 'OnePlus 9', 'Android', 512, 10.5, 2538, 1694, 41, 'Male')
# (596, 597, 'Xiaomi Mi 11', 'Android', 511, 10.8, 2529, 2387, 21, 'Male')
# (597, 598, 'OnePlus 9', 'Android', 140, 2.5, 825, 347, 59, 'Male')
# (598, 599, 'Samsung Galaxy S21', 'Android', 114, 3.0, 1131, 596, 28, 'Male')
# (599, 600, 'Samsung Galaxy S21', 'Android', 192, 4.3, 1382, 905, 47, 'Female')
# (600, 601, 'iPhone 12', 'iOS', 325, 6.0, 2244, 1296, 30, 'Female')
# (601, 602, 'OnePlus 9', 'Android', 83, 1.2, 545, 284, 44, 'Male')
# (602, 603, 'OnePlus 9', 'Android', 122, 3.0, 922, 373, 43, 'Male')
# (603, 604, 'OnePlus 9', 'Android', 138, 2.1, 660, 424, 41, 'Female')
# (604, 605, 'OnePlus 9', 'Android', 182, 5.3, 1278, 885, 54, 'Female')
# (605, 606, 'OnePlus 9', 'Android', 425, 6.0, 1928, 1150, 53, 'Female')
# (606, 607, 'OnePlus 9', 'Android', 580, 10.4, 2496, 2441, 37, 'Female')
# (607, 608, 'Xiaomi Mi 11', 'Android', 203, 4.0, 1323, 787, 21, 'Male')
# (608, 609, 'Xiaomi Mi 11', 'Android', 258, 4.9, 1596, 937, 40, 'Female')
# (609, 610, 'iPhone 12', 'iOS', 551, 8.5, 2927, 1901, 51, 'Male')
# (610, 611, 'iPhone 12', 'iOS', 507, 9.6, 2606, 1543, 48, 'Male')
# (611, 612, 'Xiaomi Mi 11', 'Android', 57, 1.3, 489, 131, 37, 'Male')
# (612, 613, 'Xiaomi Mi 11', 'Android', 553, 10.2, 2911, 2441, 44, 'Male')
# (613, 614, 'Google Pixel 5', 'Android', 49, 1.1, 395, 153, 46, 'Female')
# (614, 615, 'Samsung Galaxy S21', 'Android', 106, 4.0, 1158, 493, 18, 'Male')
# (615, 616, 'Google Pixel 5', 'Android', 119, 3.7, 608, 461, 52, 'Male')
# (616, 617, 'OnePlus 9', 'Android', 288, 5.4, 1476, 767, 36, 'Female')
# (617, 618, 'Google Pixel 5', 'Android', 225, 5.6, 1388, 965, 36, 'Female')
# (618, 619, 'OnePlus 9', 'Android', 342, 7.0, 1826, 1077, 26, 'Female')
# (619, 620, 'Samsung Galaxy S21', 'Android', 292, 4.2, 1407, 867, 59, 'Male')
# (620, 621, 'iPhone 12', 'iOS', 218, 5.0, 1475, 972, 59, 'Female')
# (621, 622, 'Google Pixel 5', 'Android', 64, 1.8, 351, 274, 56, 'Male')
# (622, 623, 'Xiaomi Mi 11', 'Android', 453, 7.4, 2363, 1046, 41, 'Female')
# (623, 624, 'OnePlus 9', 'Android', 42, 1.8, 417, 284, 21, 'Male')
# (624, 625, 'Samsung Galaxy S21', 'Android', 36, 1.5, 310, 272, 45, 'Male')
# (625, 626, 'OnePlus 9', 'Android', 55, 1.8, 328, 196, 31, 'Female')
# (626, 627, 'iPhone 12', 'iOS', 210, 5.0, 1614, 679, 55, 'Female')
# (627, 628, 'iPhone 12', 'iOS', 227, 5.2, 1446, 920, 59, 'Male')
# (628, 629, 'Xiaomi Mi 11', 'Android', 47, 1.2, 437, 234, 55, 'Male')
# (629, 630, 'iPhone 12', 'iOS', 461, 6.3, 1988, 1004, 21, 'Male')
# (630, 631, 'Google Pixel 5', 'Android', 94, 3.1, 1078, 489, 25, 'Male')
# (631, 632, 'Samsung Galaxy S21', 'Android', 216, 5.1, 1483, 977, 45, 'Female')
# (632, 633, 'iPhone 12', 'iOS', 496, 10.2, 2587, 1921, 56, 'Female')
# (633, 634, 'OnePlus 9', 'Android', 138, 3.2, 1142, 366, 29, 'Female')
# (634, 635, 'iPhone 12', 'iOS', 318, 6.6, 2055, 1253, 43, 'Male')
# (635, 636, 'Samsung Galaxy S21', 'Android', 96, 3.4, 1198, 401, 48, 'Female')
# (636, 637, 'OnePlus 9', 'Android', 510, 10.7, 2433, 1729, 47, 'Male')
# (637, 638, 'Xiaomi Mi 11', 'Android', 83, 1.1, 546, 289, 32, 'Female')
# (638, 639, 'Google Pixel 5', 'Android', 417, 6.2, 2074, 1135, 35, 'Female')
# (639, 640, 'Google Pixel 5', 'Android', 538, 9.8, 2778, 2080, 35, 'Female')
# (640, 641, 'Samsung Galaxy S21', 'Android', 63, 1.8, 321, 271, 42, 'Male')
# (641, 642, 'OnePlus 9', 'Android', 50, 1.4, 443, 255, 26, 'Female')
# (642, 643, 'Google Pixel 5', 'Android', 502, 8.2, 2597, 1553, 27, 'Male')
# (643, 644, 'OnePlus 9', 'Android', 105, 3.3, 723, 566, 46, 'Male')
# (644, 645, 'Google Pixel 5', 'Android', 186, 4.8, 1494, 949, 20, 'Female')
# (645, 646, 'Xiaomi Mi 11', 'Android', 174, 2.9, 1197, 345, 20, 'Female')
# (646, 647, 'Samsung Galaxy S21', 'Android', 89, 1.3, 314, 201, 58, 'Female')
# (647, 648, 'iPhone 12', 'iOS', 66, 1.5, 565, 283, 42, 'Female')
# (648, 649, 'iPhone 12', 'iOS', 389, 6.3, 2294, 1334, 53, 'Male')
# (649, 650, 'Xiaomi Mi 11', 'Android', 186, 5.4, 1627, 790, 31, 'Female')
# (650, 651, 'Google Pixel 5', 'Android', 149, 2.0, 1041, 356, 49, 'Male')
# (651, 652, 'iPhone 12', 'iOS', 69, 1.7, 519, 167, 51, 'Female')
# (652, 653, 'Xiaomi Mi 11', 'Android', 206, 5.2, 1632, 694, 30, 'Male')
# (653, 654, 'Samsung Galaxy S21', 'Android', 49, 1.2, 365, 144, 29, 'Male')
# (654, 655, 'Google Pixel 5', 'Android', 594, 10.5, 2839, 1647, 56, 'Male')
# (655, 656, 'Google Pixel 5', 'Android', 104, 3.7, 1028, 493, 39, 'Male')
# (656, 657, 'Google Pixel 5', 'Android', 262, 5.6, 1489, 628, 54, 'Female')
# (657, 658, 'Xiaomi Mi 11', 'Android', 278, 5.3, 1368, 894, 40, 'Female')
# (658, 659, 'Xiaomi Mi 11', 'Android', 463, 6.8, 2358, 1236, 43, 'Female')
# (659, 660, 'Xiaomi Mi 11', 'Android', 505, 9.6, 2464, 2375, 35, 'Male')
# (660, 661, 'Google Pixel 5', 'Android', 50, 1.5, 387, 146, 59, 'Male')
# (661, 662, 'Xiaomi Mi 11', 'Android', 138, 3.1, 947, 545, 48, 'Male')
# (662, 663, 'Xiaomi Mi 11', 'Android', 130, 3.2, 1189, 448, 45, 'Male')
# (663, 664, 'Google Pixel 5', 'Android', 469, 6.4, 1858, 1297, 55, 'Female')
# (664, 665, 'Xiaomi Mi 11', 'Android', 555, 10.3, 2568, 2003, 52, 'Male')
# (665, 666, 'iPhone 12', 'iOS', 198, 5.4, 1544, 635, 53, 'Male')
# (666, 667, 'Samsung Galaxy S21', 'Android', 529, 11.4, 2891, 1845, 46, 'Male')
# (667, 668, 'Samsung Galaxy S21', 'Android', 205, 5.5, 1699, 729, 36, 'Male')
# (668, 669, 'iPhone 12', 'iOS', 170, 2.4, 1039, 334, 23, 'Male')
# (669, 670, 'Samsung Galaxy S21', 'Android', 160, 3.2, 648, 339, 27, 'Female')
# (670, 671, 'iPhone 12', 'iOS', 81, 1.6, 387, 224, 48, 'Male')
# (671, 672, 'Google Pixel 5', 'Android', 468, 7.3, 1937, 1209, 22, 'Male')
# (672, 673, 'Xiaomi Mi 11', 'Android', 500, 11.2, 2925, 2438, 27, 'Male')
# (673, 674, 'Google Pixel 5', 'Android', 37, 1.6, 490, 216, 52, 'Male')
# (674, 675, 'Xiaomi Mi 11', 'Android', 522, 11.4, 2776, 1768, 27, 'Female')
# (675, 676, 'Xiaomi Mi 11', 'Android', 81, 1.5, 545, 159, 40, 'Male')
# (676, 677, 'OnePlus 9', 'Android', 141, 3.8, 689, 576, 34, 'Male')
# (677, 678, 'Samsung Galaxy S21', 'Android', 115, 3.5, 706, 495, 52, 'Female')
# (678, 679, 'Google Pixel 5', 'Android', 298, 4.6, 1525, 814, 36, 'Female')
# (679, 680, 'iPhone 12', 'iOS', 33, 1.8, 334, 113, 36, 'Female')
# (680, 681, 'Google Pixel 5', 'Android', 307, 6.1, 2105, 1111, 25, 'Female')
# (681, 682, 'Xiaomi Mi 11', 'Android', 380, 7.6, 2354, 1191, 30, 'Male')
# (682, 683, 'Xiaomi Mi 11', 'Android', 190, 5.5, 1718, 815, 42, 'Male')
# (683, 684, 'Samsung Galaxy S21', 'Android', 75, 1.6, 325, 225, 45, 'Male')
# (684, 685, 'Google Pixel 5', 'Android', 218, 4.0, 1221, 822, 25, 'Male')
# (685, 686, 'Xiaomi Mi 11', 'Android', 412, 6.6, 1859, 1393, 18, 'Male')
# (686, 687, 'Google Pixel 5', 'Android', 335, 7.7, 2037, 1007, 18, 'Male')
# (687, 688, 'OnePlus 9', 'Android', 387, 6.3, 2098, 1178, 54, 'Male')
# (688, 689, 'Google Pixel 5', 'Android', 261, 4.9, 1589, 824, 52, 'Female')
# (689, 690, 'Samsung Galaxy S21', 'Android', 541, 9.5, 2424, 1550, 32, 'Male')
# (690, 691, 'Google Pixel 5', 'Android', 195, 5.7, 1447, 679, 30, 'Male')
# (691, 692, 'iPhone 12', 'iOS', 178, 4.0, 856, 569, 51, 'Female')
# (692, 693, 'Xiaomi Mi 11', 'Android', 378, 6.7, 1898, 1455, 48, 'Female')
# (693, 694, 'Xiaomi Mi 11', 'Android', 505, 8.6, 2792, 1709, 31, 'Male')
# (694, 695, 'Samsung Galaxy S21', 'Android', 564, 9.7, 2422, 1985, 34, 'Female')
# (695, 696, 'iPhone 12', 'iOS', 92, 3.9, 1082, 381, 22, 'Male')
# (696, 697, 'Xiaomi Mi 11', 'Android', 316, 6.8, 1965, 1201, 59, 'Male')
# (697, 698, 'Google Pixel 5', 'Android', 99, 3.1, 942, 457, 50, 'Female')
# (698, 699, 'Samsung Galaxy S21', 'Android', 62, 1.7, 431, 224, 44, 'Male')
# (699, 700, 'OnePlus 9', 'Android', 212, 5.4, 1306, 828, 23, 'Female')

# %%
try:
    # Convert JSON data to CSV
    earthquake_df = pd.DataFrame(pd.json_normalize(earthquake_json['features']))
except:
    print("Something went wrong converting the JSON data to CSV.")

try:
    # Dropping 5 columns
    earthquake_df.drop(columns=['properties.tz', 'properties.felt', 'properties.mmi', 'properties.cdi', 'properties.alert'], inplace=True)
except:
    print("Something went wrong dropping columns from the DataFrame. Make sure they haven't already been removed.")

if out_format_2 == "CSV":
    try:
        # Showing Output
        print("# of cols:", len(earthquake_df.count()))
        print("# of records:", len(earthquake_df.count('columns')), "\n")
        print(earthquake_df.head())
        # Writing CSV data to file
        earthquake_df.to_csv('earthquake.csv')
    except:
        print("Something went wrong writing the CSV data to file. Check your filepath.")
    
# Convert DataFrame to SQL table
else:
    try:
        earthquake_df['geometry.coordinates'] = earthquake_df['geometry.coordinates'].astype(str)
        earthquake_df.to_sql('quakeData', connection)
    
        # Showing Output
        numCols = 0
        for row in cursor.execute("pragma table_info(quakeData)"):
            numCols += 1
        print("# of cols:", numCols - 1)
        print("# of records:", len(cursor.execute("select * from quakeData").fetchall()), "\n")
        rows = cursor.execute("""
        select * from quakeData
        """)
        for row in rows:
            print(row)
    except:
        print("Something went wrong converting the DataFrame to SQL or writing to the database. Check that the table doesn't already exist.")
# Out:
# # of cols: 25
# # of records: 9
#
# (0, 'Feature', 'ak024dilwc3a', 1.6, '17 km NE of Petersville, Alaska', 1729467261342, 1729467382777, 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilwc3a', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilwc3a.geojson', 'automatic', 0, 39, 'ak', '024dilwc3a', ',ak024dilwc3a,', ',ak,', ',origin,phase-data,', None, None, 1.19, None, 'ml', 'earthquake', 'M 1.6 - 17 km NE of Petersville, Alaska', 'Point', '[-150.5302, 62.6138, 16.9]')
# (1, 'Feature', 'nc75076581', 1.02, '7 km NW of Parkfield, CA', 1729466916860, 1729467014777, 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75076581', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75076581.geojson', 'automatic', 0, 16, 'nc', '75076581', ',nc75076581,', ',nc,', ',nearby-cities,origin,phase-data,', 11.0, 0.01546, 0.05, 148.0, 'md', 'earthquake', 'M 1.0 - 7 km NW of Parkfield, CA', 'Point', '[-120.488670349121, 35.9396667480469, 9.86999988555908]')
# (2, 'Feature', 'us6000nzxu', 5.0, '166 km NNW of Sola, Vanuatu', 1729466537999, 1729467505040, 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nzxu', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nzxu.geojson', 'reviewed', 0, 385, 'us', '6000nzxu', ',us6000nzxu,', ',us,', ',origin,phase-data,', 54.0, 8.431, 0.55, 53.0, 'mb', 'earthquake', 'M 5.0 - 166 km NNW of Sola, Vanuatu', 'Point', '[166.9805, -12.479, 205.772]')
# (3, 'Feature', 'ak024dilt50w', 1.4, '25 km NW of Valdez, Alaska', 1729466370088, 1729466462327, 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilt50w', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilt50w.geojson', 'automatic', 0, 30, 'ak', '024dilt50w', ',ak024dilt50w,', ',ak,', ',origin,phase-data,', None, None, 0.2, None, 'ml', 'earthquake', 'M 1.4 - 25 km NW of Valdez, Alaska', 'Point', '[-146.7151, 61.2805, 27.9]')
# (4, 'Feature', 'ci40958112', 2.47, '42 km NE of San Clemente Is. (SE tip), CA', 1729466197470, 1729466612848, 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40958112', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40958112.geojson', 'automatic', 0, 94, 'ci', '40958112', ',ci40958112,', ',ci,', ',nearby-cities,origin,phase-data,scitech-link,', 37.0, 0.4044, 0.28, 127.0, 'ml', 'earthquake', 'M 2.5 - 42 km NE of San Clemente Is. (SE tip), CA', 'Point', '[-117.9855, 33.054, 13.1]')
# (5, 'Feature', 'ci40958104', 3.07, '41 km NE of San Clemente Is. (SE tip), CA', 1729465918070, 1729466722507, 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40958104', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40958104.geojson', 'automatic', 0, 146, 'ci', '40958104', ',ci40958104,us6000nzxl,', ',ci,us,', ',dyfi,nearby-cities,origin,phase-data,scitech-link,', 76.0, 0.4196, 0.38, 182.0, 'ml', 'earthquake', 'M 3.1 - 41 km NE of San Clemente Is. (SE tip), CA', 'Point', '[-117.9840012, 33.0336685, 5.54]')
# (6, 'Feature', 'ak024dilqi8d', 1.2, '10 km ENE of Fox, Alaska', 1729465621578, 1729465736503, 'https://earthquake.usgs.gov/earthquakes/eventpage/ak024dilqi8d', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak024dilqi8d.geojson', 'automatic', 0, 22, 'ak', '024dilqi8d', ',ak024dilqi8d,', ',ak,', ',origin,phase-data,', None, None, 0.34, None, 'ml', 'earthquake', 'M 1.2 - 10 km ENE of Fox, Alaska', 'Point', '[-147.3996, 64.9836, 3.8]')
# (7, 'Feature', 'us6000nzxj', 5.7, '63 km NNW of Albardón, Argentina', 1729465180810, 1729468291987, 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000nzxj', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nzxj.geojson', 'reviewed', 0, 508, 'us', '6000nzxj', ',us6000nzxj,', ',us,', ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,', 32.0, 0.652, 0.53, 89.0, 'mww', 'earthquake', 'M 5.7 - 63 km NNW of Albardón, Argentina', 'Point', '[-68.7474, -30.8936, 107.654]')
# (8, 'Feature', 'nc75076571', 1.5, '9 km ENE of Cayucos, CA', 1729464938110, 1729467867923, 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75076571', 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc75076571.geojson', 'automatic', 0, 35, 'nc', '75076571', ',nc75076571,', ',nc,', ',nearby-cities,origin,phase-data,scitech-link,', 10.0, 0.07483, 0.05, 96.0, 'md', 'earthquake', 'M 1.5 - 9 km ENE of Cayucos, CA', 'Point', '[-120.797836303711, 35.4781684875488, 6.44000005722046]')
